# %%
import pandas as pd

# %%
nfl = pd.read_csv("nfl_cleaned.csv")
nba = pd.read_csv("nba_cleaned.csv")
mlb = pd.read_csv("mlb_cleaned.csv")


datasets_merged = pd.concat([nfl, nba, mlb], ignore_index=True)

datasets_merged
# Out:
#     Team_Name        City  From    To       W       L  Win_Percentage  \
# 0   Cardinals     Arizona  1920  2026     596     826           0.419
# 1     Falcons     Atlanta  1966  2026     406     521           0.438
# 2      Ravens   Baltimore  1996  2026     276     208           0.570
# 3       Bills     Buffalo  1960  2026     498     510           0.494
# 4    Panthers    Carolina  1995  2026     227     273           0.454
# ..        ...         ...   ...   ...     ...     ...             ...
# 87  Cardinals   St. Louis  1882  2026  11,371  10,494           0.520
# 88       Rays   Tampa Bay  1998  2026   2,176   2,271           0.489
# 89    Rangers       Texas  1961  2026   4,908   5,390           0.477
# 90  Blue Jays     Toronto  1977  2026   3,861   3,865           0.500
# 91  Nationals  Washington  1969  2026   4,338   4,674           0.481
#
#     Years_In_Playoffs  Championships  Championships_Conference  \
# 0                  11              0                         1
# 1                  14              0                         2
# 2                  16              2                         2
# 3                  25              0                         4
# 4                   9              0                         2
# ..                ...            ...                       ...
# 87                 32             11                        23
# 88                  9              0                         2
# 89                  9              1                         3
# 90                 11              2                         3
# 91                  6              1                         1
#
#     Championships_Division
# 0                        8
# 1                        7
# 2                        8
# 3                       16
# 4                        7
# ..                     ...
# 87                      15
# 88                       4
# 89                       7
# 90                       7
# 91                       5
#
# [92 rows x 11 columns]

# %%
datasets_merged.to_csv("city-sports-merged.csv", index=False)
